# %% [markdown]
# # Welcome to your first assignment!
#
# Instructions are below. Please give this a try, and look in the solutions folder if you get stuck (or feel free to ask me!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get to the assignment --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Some examples include:
#
# 1. **Content Generation**: Generative AI can be used to generate high-quality content such as articles, social media posts, product descriptions, and more. This can help businesses save time and resources, while also providing a consistent tone and style.
# 2. **Marketing Automation**: Generative AI can be used to create personalized marketing messages, emails, and ads based on customer data and behavior. This can help businesses increase engagement and conversion rates.
# 3. **Product Design**: Generative AI can be used to design new product concepts, prototypes, and even entire product lines. This can help businesses reduce the time and cost associated with traditional product development processes.
# 4. **Image and Video Generation**: Generative AI can be used to create realistic images and videos for use in advertising, marketing, and other applications.
# 5. **Chatbots and Virtual Assistants**: Generative AI can be used to power chatbots and virtual assistants that provide customer support, answer frequently asked questions, and help with tasks such as booking appointments or making reservations.
# 6. **Data Analysis and Visualization**: Generative AI can be used to analyze large datasets and generate visualizations such as charts, graphs, and maps.
# 7. **Predictive Maintenance**: Generative AI can be used to predict equipment failures and perform predictive maintenance, reducing downtime and increasing overall efficiency.
# 8. **Customer Service**: Generative AI can be used to power personalized customer service, providing customers with relevant information and support based on their behavior and preferences.
# 9. **Supply Chain Optimization**: Generative AI can be used to optimize supply chain operations, predicting demand, managing inventory, and identifying bottlenecks in the supply chain.
# 10. **Financial Modeling**: Generative AI can be used to create financial models that simulate different scenarios, allowing businesses to predict revenue, expenses, and cash flows.
#
# Some specific examples of companies using generative AI include:
#
# * **Amazon**: Using generative AI to power its Alexa virtual assistant
# * **Google**: Using generative AI to generate high-quality images and videos for use in advertising and marketing
# * **Netflix**: Using generative AI to create personalized content recommendations for its customers
# * **Microsoft**: Using generative AI to create personalized customer service experiences using its chatbot technology
# * **Procter & Gamble**: Using generative AI to design new product concepts and prototypes
#
# These are just a few examples of the many business applications of generative AI. As the technology continues to evolve, we can expect to see even more innovative uses in various industries.

# %% [markdown]
# # Introducing the ollama package
#
# And now we'll do the same thing, but using the elegant ollama python package instead of a direct HTTP call.
#
# Under the hood, it's making the same call as above to the ollama server running at localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Creation**: Generative AI can generate high-quality content such as articles, social media posts, product descriptions, and even entire books. This can help businesses streamline their content creation process, reduce costs, and increase productivity.
# 2. **Marketing Automation**: Generative AI can be used to create personalized marketing messages, emails, and advertisements that are tailored to individual customers' needs and preferences.
# 3. **Product Design**: Generative AI can aid in the design of new products by generating 2D and 3D models, prototypes, and even entire product lines. This can help businesses quickly iterate on designs and reduce development time.
# 4. **Image and Video Generation**: Generative AI can create realistic images and videos that can be used for various applications such as advertising, entertainment, and educational purposes.
# 5. **Chatbots and Virtual Assistants**: Generative AI can power chatbots and virtual assistants that can engage with customers, provide customer support, and answer frequently asked questions.
# 6. **Predictive Analytics**: Generative AI can analyze large datasets to identify patterns and predict future trends, helping businesses make informed decisions about investments, resource allocation, and risk management.
# 7. **Supply Chain Optimization**: Generative AI can optimize supply chain operations by predicting demand, identifying bottlenecks, and recommending the most efficient routes for goods transportation.
# 8. **Financial Modeling**: Generative AI can create complex financial models that simulate different scenarios, helping businesses forecast revenue, expenses, and cash flow.
# 9. **Customer Service**: Generative AI can help provide personalized customer service by generating responses to common questions, freeing up human customer support agents to focus on more complex issues.
# 10. **Innovation**: Generative AI can aid in the discovery of new ideas and innovations by analyzing large datasets and identifying patterns that may not have been apparent to humans.
#
# Some specific examples of businesses using generative AI include:
#
# * Autodesk using generative AI to design and manufacture customized parts for aerospace and automotive industries
# * IBM using generative AI to create personalized customer experiences and improve supply chain efficiency
# * Coca-Cola using generative AI to generate content, such as social media posts and product descriptions
# * NVIDIA using generative AI to power their graphics and gaming products
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative uses in various industries.

# %% [markdown]
# ## Alternative approach - using OpenAI python library to connect to Ollama

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Generation**: Generative AI can create high-quality content such as articles, blog posts, social media posts, and product descriptions, reducing the need for human writers.
# 2. **Graphic Design**: AI-generated graphics, logos, and branding materials can streamline design processes, saving time and resources.
# 3. **Marketing Automation**: Generative AI can help personalize marketing messages, predict customer behavior, and create targeted ads, leading to improved engagement and conversion rates.
# 4. **Virtual Customer Assistants**: Chatbots powered by generative AI can provide 24/7 support, answer customer queries, and route complex issues to human representatives.
# 5. **Sales Forecasting**: Generative AI models can analyze historical sales data, identify trends, and predict future demand, enabling businesses to make more informed sales strategies.
# 6. **Product Design**: AI-generated product designs can help manufacturers reduce development costs, improve design aesthetics, and accelerate time-to-market for new products.
# 7. **Supply Chain Optimization**: Generative AI algorithms can analyze supply chain data, identify bottlenecks, and optimize routes to reduce costs, lead times, and logistics disruptions.
# 8. **Analytics and Reporting**: AI-generated reports and dashboards can help businesses track key performance indicators (KPIs), identify areas for improvement, and make more informed decisions.
# 9. **Email Marketing Personalization**: Generative AI can analyze customer behavior, preferences, and interests to create personalized email campaigns that drive engagement and conversion rates.
# 10. **Human Resource Management**: AI-generated recruitment chatbots and candidate matching tools can streamline talent acquisition processes, improving time-to-hire and reducing costs.
#
# Some of the key industries benefiting from generative AI include:
#
# 1. Retail: Personalized product recommendations, automated customer support, and supply chain optimization
# 2. Finance: Risk analysis, portfolio management, and customer risk assessment
# 3. Healthcare: Medical image analysis, patient data analysis, and personalized treatment planning
# 4. Marketing: Content generation, social media management, and campaign optimization
# 5. Education: Personalized learning experiences, student profiling, and automated grading
#
# These are just a few examples of the many business applications of generative AI. As this technology continues to evolve, we can expect to see even more innovative use cases across various industries.

# %% [markdown]
# ## Are you confused about why that works?
#
# It seems strange, right? We just used OpenAI code to call Ollama?? What's going on?!
#
# Here's the scoop:
#
# The python class `OpenAI` is simply code written by OpenAI engineers that makes calls over the internet to an endpoint.
#
# When you call `openai.chat.completions.create()`, this python code just makes a web request to the following url: "https://api.openai.com/v1/chat/completions"
#
# Code like this is known as a "client library" - it's just wrapper code that runs on your machine to make web requests. The actual power of GPT is running on OpenAI's cloud behind this API, not on your computer!
#
# OpenAI was so popular, that lots of other AI providers provided identical web endpoints, so you could use the same approach.
#
# So Ollama has an endpoint running on your local box at http://localhost:11434/v1/chat/completions
# And in week 2 we'll discover that lots of other providers do this too, including Gemini and DeepSeek.
#
# And then the team at OpenAI had a great idea: they can extend their client library so you can specify a different 'base url', and use their library to call any compatible API.
#
# That's it!
#
# So when you say: `ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')`
# Then this will make the same endpoint calls, but to Ollama instead of OpenAI.

# %% [markdown]
# ## Also trying the amazing reasoning model DeepSeek
#
# Here we use the version of DeepSeek-reasoner that's been distilled to 1.5B.
# This is actually a 1.5B variant of Qwen that has been fine-tuned using synethic data generated by Deepseek R1.
#
# Other sizes of DeepSeek are [here](https://ollama.com/library/deepseek-r1) all the way up to the full 671B parameter version, which would use up 404GB of your drive and is far too large for most!

# %%
# !ollama pull deepseek-r1:1.5b

# %%
# This may take a few minutes to run! You should then see a fascinating "thinking" trace inside <think> tags, followed by some decent definitions

response = ollama_via_openai.chat.completions.create(
    model="deepseek-r1:1.5b",
    messages=[{"role": "user", "content": "Please give definitions of some core concepts behind LLMs: a neural network, attention and the transformer"}]
)

print(response.choices[0].message.content)
# Out:
# <think>
# Okay, so I'm trying to understand the core concepts behind large language models (LLMs) that have emerged in recent years. The user asked for definitions of neural networks, attention, and transformers as part of explaining these models. Let me break this down step by step.
#
# First, I need a clear understanding of what a neural network is. From what I know, neural networks are composed of layers of interconnected nodes or units. These units process information in a way that resembles the neurons found in the human-brained nervous system. Each layer processes data through non-linear activation functions, which help model complex patterns. So, in essence, a neural network is a computational model inspired by biological systems to recognize and map input to output.
#
# Next, attention. The term attention sounds familiar from AI, especially in areas like machine translation or image recognition. I think it's about how models focus on specific parts of the input data when processing information. For example, imagine how an AI looks at different regions of an image simultaneously. Maybe using some sort of " Attention gate " that determines which part is most relevant for the current task and adjusts its representation accordingly to integrate efficiently.
#
# Then, transformers. This is a bit trickier for me because I'm more familiar with language models like GPT, which use recursive self-attention mechanisms in their context window. From what I remember, transformers have multiple layers (like blocks that handle different n-grams) but the key difference from traditional neural networks might be the introduction of " attention". Wait, aren't modern models more like transformers than deep neural networks because they incorporate attention more effectively?
#
# I'm also thinking about how these components work together. For instance, a transformer processes input token by token while maintaining attention over different parts. This makes it easier to connect higher-order n-grams in the model without having to add layers for recursive operations. However, traditional approaches using feed-forward networks required multiple layers to capture dependencies at various levels.
#
# But wait, I should check if they're all part of transformers. So maybe the initial models (like GPT's original), which used RNNs (recurrent neural networks) because they were simpler and could work without attention, but more recent developments have transitioned to transformers using attention mechanisms across multiple layers. That would make sense since attention allows models to attend to arbitrary positions in the input step by step, making the model much more flexible for generating text.
#
# I'm also wondering about how GPT-3 works. In GPT-2, each decoder block is a feed-forward network that doesn't use attention during training, which was computationally intensive due to all forward passes requiring O(N^2) operations for N tokens in a sequence of length L. But the memory and computation limits led researchers to switch strategies.
#
# In contrast, GPT-3 uses a more modern approach where each layer is a transformer block using self-attention layers. Self-attention allows each module to attend to all other modules in parallel within an operation. So during training, one part of the model can focus on another without needing multiple forward passes with interleaved attention processing.
#
# Another point I should think about is how attention contributes to parallelism and distributed computation. In traditional deep networks, attention was more localized and sequential, which meant higher layers couldn't effectively use information from lower layers because they didn't attend together. With transformers, attention becomes a way of handling parallelism without requiring extra operations, making the model faster by enabling each layer to process data in an efficient way.
#
# I'm also considering potential issues with transformers. Maybe their implementation is complex and requires careful tuning due to parameters like those in the self-attention layers. High-dimensional parameter counts could be a challenge for modern GPUs and AI hardware. This would make traditional approaches using recurrent units or feed-forward networks more feasible before transformers became widespread.
#
# In summary, to outline each component:
#
# 1. Neural network: Inspired by biological neurons with interconnected layers that process data through non-linear activations.
# 2. Attention: The mechanism where models selectively focus on certain parts of the input or different time steps simultaneously.
# 3. Transformers: A architectural structure in which multi-head attention is used intra-layerly, allowing processing of inputs while maintaining parallelism across different dimensions during each step.
#
# These components together form the foundation of modern LLMs, enabling them to handle complex tasks and adapt to diverse domains effectively.
# </think>
#
# Large Language Models (LLMs) are advanced technologies built on fundamental biological inspiration from neural networks. Here's a structured breakdown of key concepts:
#
# 1. **Neural Network**: Inspired by biological neurons with interconnected layers, which process data through non-linear activation functions to recognize patterns, map inputs to outputs.
#
# 2. **Attention Mechanism**: Focuses on selectively focusing on specific parts of the input or different time steps simultaneously, enabling efficient handling of complex data and allowing higher-level tasks to utilize information from lower levels efficiently.
#
# 3. **Transformers (LMCs)**: A modern architectural structure that uses self-attention intra-layerly, enabling parallelism without requiring interleaved attention processing. Unlike traditional RNNs or feed-forward networks, transformers overcome computational bottlenecks by processing inputs in a way that enhances speed and efficiency.
#
# These components together form the foundation of modern LLMs, enabling them to generate text effectively through mechanisms like GPT-3. Key differences include the use of more advanced attention structures compared to traditional models like RNNs or feed-forward networks, allowing for parallel computation with fewer high-dimensional parameters.

# %% [markdown]
# # NOW the exercise for you
#
# Take the code from day1 and incorporate it here, to build a website summarizer that uses Llama 3.2 running locally instead of OpenAI; use either of the above approaches.
